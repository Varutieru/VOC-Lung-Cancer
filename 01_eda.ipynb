# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_raw = pd.read_excel("VOC_LungCancer_Simulation_Singapore.xlsx", 
                        sheet_name="VOC SENSOR RAW DATA", 
                        header=1)

df_features = pd.read_excel("VOC_LungCancer_Simulation_Singapore.xlsx",
                              sheet_name="SIGNAL PROCESSING",
                              header=1)

df_ai = pd.read_excel("VOC_LungCancer_Simulation_Singapore.xlsx",
                       sheet_name="AI INFERENCE",
                       header=1)

print("Raw data shape    :", df_raw.shape)
print("Features shape    :", df_features.shape)
print("AI inference shape:", df_ai.shape)
print("\nFirst patient:")
print(df_ai.iloc[0])
